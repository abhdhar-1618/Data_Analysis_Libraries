# %%
import pandas as pd

# %%
df = pd.read_csv("sales_data.csv", encoding="Latin-1")  # Load the data

df.head()  # Show first five rows
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
#
# [5 rows x 25 columns]

# %%
df.tail() # It displays the last five rows of the sample data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# 2818     C/ Moralzarzal, 86           NaN    Madrid   NaN      28034    Spain
# 2819            Torikatu 38           NaN      Oulu   NaN      90110  Finland
# 2820     C/ Moralzarzal, 86           NaN    Madrid   NaN      28034    Spain
# 2821  1 rue Alsace-Lorraine           NaN  Toulouse   NaN      31000   France
# 2822     8616 Spinnaker Dr.           NaN    Boston    MA      51003      USA
#
#      TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 2818      EMEA          Freyre            Diego    Small
# 2819      EMEA       Koskitalo           Pirkko   Medium
# 2820      EMEA          Freyre            Diego   Medium
# 2821      EMEA          Roulet          Annette    Small
# 2822       NaN         Yoshido             Juri   Medium
#
# [5 rows x 25 columns]

# %%
df.sample(6) # df.sample(n): It displays the random n number of rows in the sample data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 923         10280               43      68.71                5  2954.53
# 1344        10126               43      53.83                9  2314.69
# 479         10149               50     100.00                4  5907.50
# 235         10370               49     100.00                8  8470.14
# 2743        10106               48      61.44               10  2949.12
# 1427        10279               32      74.96                5  2398.72
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 923   8/17/2004 0:00  Shipped       3         8     2004  ...
# 1344  5/28/2003 0:00  Shipped       2         5     2003  ...
# 479   9/12/2003 0:00  Shipped       3         9     2003  ...
# 235   1/20/2005 0:00  Shipped       1         1     2005  ...
# 2743  2/17/2003 0:00  Shipped       1         2     2003  ...
# 1427   8/9/2004 0:00  Shipped       3         8     2004  ...
#
#                  ADDRESSLINE1  ADDRESSLINE2          CITY STATE POSTALCODE  \
# 923       Via Monte Bianco 34           NaN        Torino   NaN      10100
# 1344           C/ Araquil, 67           NaN        Madrid   NaN      28023
# 479         2793 Furth Circle           NaN      Brisbane    CA      94217
# 235         201 Miller Street      Level 15  North Sydney   NSW       2060
# 2743  Via Ludovico il Moro 22           NaN       Bergamo   NaN      24100
# 1427       C/ Moralzarzal, 86           NaN        Madrid   NaN      28034
#
#         COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 923       Italy      EMEA         Accorti            Paolo    Small
# 1344      Spain      EMEA          Sommer           Mart¡n    Small
# 479         USA       NaN          Taylor              Sue   Medium
# 235   Australia      APAC          O'Hara             Anna    Large
# 2743      Italy      EMEA         Rovelli         Giovanni    Small
# 1427      Spain      EMEA          Freyre            Diego    Small
#
# [6 rows x 25 columns]

# %%
df.shape #It displays the sample data's rows and columns (dimensions).
# Out:
# (2823, 25)

# %%
df.describe() # Get the basic statistics of each column of the sample data
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# 25%     2203.430000     2.000000     4.000000  2003.00000    68.000000
# 50%     3184.800000     3.000000     8.000000  2004.00000    99.000000
# 75%     4508.000000     4.000000    11.000000  2004.00000   124.000000
# max    14082.800000     4.000000    12.000000  2005.00000   214.000000

# %%
df.info()  # Get the information about the various data types used and the non-null count of each column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
#  16  ADDRESSLINE2      302 non-null    object
#  17  CITY              2823 non-null   object
#  18  STATE             1337 non-null   object
#  19  POSTALCODE        2747 non-null   object
#  20  COUNTRY           2823 non-null   object
#  21  TERRITORY         1749 non-null   object
#  22  CONTACTLASTNAME   2823 non-null   object
#  23  CONTACTFIRSTNAME  2823 non-null   object
#  24  DEALSIZE          2823 non-null   object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 551.5+ KB

# %%
df.columns # Get the column headers of the sample data
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.corr()  # This can give you the correlation matrix between all the integer columns in the data frame.
# Out:
# C:\Users\Abhik\AppData\Local\Temp\ipykernel_9772\3382535500.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()  # This can give you the correlation matrix between all the integer columns in the data frame.
#                  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# ORDERNUMBER         1.000000         0.065543  -0.002935        -0.055550
# QUANTITYORDERED     0.065543         1.000000   0.005564        -0.018397
# PRICEEACH          -0.002935         0.005564   1.000000        -0.020965
# ORDERLINENUMBER    -0.055550        -0.018397  -0.020965         1.000000
# SALES               0.039919         0.551426   0.657841        -0.058400
# QTR_ID             -0.051383        -0.035323   0.008712         0.040716
# MONTH_ID           -0.039723        -0.039048   0.005152         0.034016
# YEAR_ID             0.904596         0.069535  -0.005938        -0.057367
# MSRP               -0.010280         0.017881   0.670625        -0.021067
#
#                     SALES    QTR_ID  MONTH_ID   YEAR_ID      MSRP
# ORDERNUMBER      0.039919 -0.051383 -0.039723  0.904596 -0.010280
# QUANTITYORDERED  0.551426 -0.035323 -0.039048  0.069535  0.017881
# PRICEEACH        0.657841  0.008712  0.005152 -0.005938  0.670625
# ORDERLINENUMBER -0.058400  0.040716  0.034016 -0.057367 -0.021067
# SALES            1.000000 -0.006796 -0.009605  0.035647  0.635239
# QTR_ID          -0.006796  1.000000  0.979300 -0.433052  0.010234
# MONTH_ID        -0.009605  0.979300  1.000000 -0.430163  0.008170
# YEAR_ID          0.035647 -0.433052 -0.430163  1.000000 -0.014310
# MSRP             0.635239  0.010234  0.008170 -0.014310  1.000000

# %%
df.memory_usage()  # It will tell you how much memory is being consumed by each column.
# Out:
# Index                 132
# ORDERNUMBER         22584
# QUANTITYORDERED     22584
# PRICEEACH           22584
# ORDERLINENUMBER     22584
# SALES               22584
# ORDERDATE           22584
# STATUS              22584
# QTR_ID              22584
# MONTH_ID            22584
# YEAR_ID             22584
# PRODUCTLINE         22584
# MSRP                22584
# PRODUCTCODE         22584
# CUSTOMERNAME        22584
# PHONE               22584
# ADDRESSLINE1        22584
# ADDRESSLINE2        22584
# CITY                22584
# STATE               22584
# POSTALCODE          22584
# COUNTRY             22584
# TERRITORY           22584
# CONTACTLASTNAME     22584
# CONTACTFIRSTNAME    22584
# DEALSIZE            22584
# dtype: int64

# %%
#df.iloc[row_num]:  It will select a particular row based on its index

df.iloc[923]
# Out:
# ORDERNUMBER                       10280
# QUANTITYORDERED                      43
# PRICEEACH                         68.71
# ORDERLINENUMBER                       5
# SALES                           2954.53
# ORDERDATE                8/17/2004 0:00
# STATUS                          Shipped
# QTR_ID                                3
# MONTH_ID                              8
# YEAR_ID                            2004
# PRODUCTLINE                Vintage Cars
# MSRP                                 62
# PRODUCTCODE                    S18_2957
# CUSTOMERNAME         Amica Models & Co.
# PHONE                       011-4988555
# ADDRESSLINE1        Via Monte Bianco 34
# ADDRESSLINE2                        NaN
# CITY                             Torino
# STATE                               NaN
# POSTALCODE                        10100
# COUNTRY                           Italy
# TERRITORY                          EMEA
# CONTACTLASTNAME                 Accorti
# CONTACTFIRSTNAME                  Paolo
# DEALSIZE                          Small
# Name: 923, dtype: object

# %%
# df["col_name"]: It will select the particular column

df["POSTALCODE"]
# Out:
# 0       10022
# 1       51100
# 2       75508
# 3       90003
# 4         NaN
#         ...
# 2818    28034
# 2819    90110
# 2820    28034
# 2821    31000
# 2822    51003
# Name: POSTALCODE, Length: 2823, dtype: object

# %%
## For multiples

df[["SALES", "PRICEEACH"]]
# Out:
#         SALES  PRICEEACH
# 0     2871.00      95.70
# 1     2765.90      81.35
# 2     3884.34      94.74
# 3     3746.70      83.26
# 4     5205.27     100.00
# ...       ...        ...
# 2818  2244.40     100.00
# 2819  3978.51     100.00
# 2820  5417.57     100.00
# 2821  2116.16      62.24
# 2822  3079.44      65.52
#
# [2823 rows x 2 columns]

# %%
# df.isnull(): This will identify the missing values in your dataframe.

df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2818        False            False      False            False  False
# 2819        False            False      False            False  False
# 2820        False            False      False            False  False
# 2821        False            False      False            False  False
# 2822        False            False      False            False  False
#
#       ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  ADDRESSLINE1  \
# 0         False   False   False     False    False  ...         False
# 1         False   False   False     False    False  ...         False
# 2         False   False   False     False    False  ...         False
# 3         False   False   False     False    False  ...         False
# 4         False   False   False     False    False  ...         False
# ...         ...     ...     ...       ...      ...  ...           ...
# 2818      False   False   False     False    False  ...         False
# 2819      False   False   False     False    False  ...         False
# 2820      False   False   False     False    False  ...         False
# 2821      False   False   False     False    False  ...         False
# 2822      False   False   False     False    False  ...         False
#
#       ADDRESSLINE2   CITY  STATE  POSTALCODE  COUNTRY  TERRITORY  \
# 0             True  False  False       False    False       True
# 1             True  False   True       False    False      False
# 2             True  False   True       False    False      False
# 3             True  False  False       False    False       True
# 4             True  False  False        True    False       True
# ...            ...    ...    ...         ...      ...        ...
# 2818          True  False   True       False    False      False
# 2819          True  False   True       False    False      False
# 2820          True  False   True       False    False      False
# 2821          True  False   True       False    False      False
# 2822          True  False  False       False    False       True
#
#       CONTACTLASTNAME  CONTACTFIRSTNAME  DEALSIZE
# 0               False             False     False
# 1               False             False     False
# 2               False             False     False
# 3               False             False     False
# 4               False             False     False
# ...               ...               ...       ...
# 2818            False             False     False
# 2819            False             False     False
# 2820            False             False     False
# 2821            False             False     False
# 2822            False             False     False
#
# [2823 rows x 25 columns]

# %%
# df.dropna(): This will remove the rows containing missing values in any column.
# df.fillna(val): This will fill the missing values with val given in the argument.
# df[‘col’].astype(new_data_type): It can convert the data type of the selected columns to a different data type.


# For ex-,
# df["SALES"].astype(int)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# ## Aggregation Functions:

# %%
#You can group a column by its name and then apply some aggregation functions like sum, min/max, mean, etc.

# df.groupby("col_name_1").agg({"col_name_2": "sum"})

# The below code will give you total order number of each city

df.groupby("CITY").agg({"ORDERNUMBER": "sum"})
# Out:
#               ORDERNUMBER
# CITY
# Aaarhus            276642
# Allentown          319272
# Barcelona          235596
# Bergamo            489268
# Bergen             295737
# ...                   ...
# Toulouse           204529
# Tsawassen          266782
# Vancouver          225709
# Versailles         185384
# White Plains       266878
#
# [73 rows x 1 columns]

# %%
# If you want to apply multiple aggregations at a single time, you can write them like that.

#For ex-,

aggregation = df.agg({"SALES": "sum", "QUANTITYORDERED": "mean"})
aggregation
# Out:
# SALES              1.003263e+07
# QUANTITYORDERED    3.509281e+01
# dtype: float64

# %%
# We can filter the data in rows based on a specific value or a condition.

# For ex- below code Displays the rows where the value of sales is greater than 5000,

df[df["SALES"] > 5000]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49      100.0               14  5205.27
# 7           10188               48      100.0                1  5512.32
# 20          10341               41      100.0                9  7737.93
# 25          10417               66      100.0                2  7516.08
# 26          10103               26      100.0               11  5404.62
# ...           ...              ...        ...              ...      ...
# 2685        10361               44      100.0               10  5001.92
# 2686        10375               44      100.0               11  5208.72
# 2689        10401               77       92.0                9  7084.00
# 2715        10397               48      100.0                3  5192.64
# 2820        10386               43      100.0                4  5417.57
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# 7     11/18/2003 0:00   Shipped       4        11     2003  ...
# 20    11/24/2004 0:00   Shipped       4        11     2004  ...
# 25     5/13/2005 0:00  Disputed       2         5     2005  ...
# 26     1/29/2003 0:00   Shipped       1         1     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2685  12/17/2004 0:00   Shipped       4        12     2004  ...
# 2686    2/3/2005 0:00   Shipped       1         2     2005  ...
# 2689    4/3/2005 0:00   On Hold       2         4     2005  ...
# 2715   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2820    3/1/2005 0:00  Resolved       1         3     2005  ...
#
#                                  ADDRESSLINE1  ADDRESSLINE2           CITY  \
# 4                             7734 Strong St.           NaN  San Francisco
# 7                 Drammen 121, PR 744 Sentrum           NaN         Bergen
# 20                                Geislweg 14           NaN       Salzburg
# 25                         C/ Moralzarzal, 86           NaN         Madrid
# 26                     Erling Skakkes gate 78           NaN        Stavern
# ...                                       ...           ...            ...
# 2685  Monitor Money Building, 815 Pacific Hwy       Level 6      Chatswood
# 2686             67, rue des Cinquante Otages           NaN         Nantes
# 2689                            7476 Moss Rd.           NaN         Newark
# 2715                    1 rue Alsace-Lorraine           NaN       Toulouse
# 2820                       C/ Moralzarzal, 86           NaN         Madrid
#
#      STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 4       CA        NaN        USA       NaN           Brown            Julie
# 7      NaN     N 5804     Norway      EMEA          Oeztan           Veysel
# 20     NaN       5020    Austria      EMEA           Pipps            Georg
# 25     NaN      28034      Spain      EMEA          Freyre            Diego
# 26     NaN       4110     Norway      EMEA      Bergulfsen            Jonas
# ...    ...        ...        ...       ...             ...              ...
# 2685   NSW       2067  Australia      APAC          Huxley           Adrian
# 2686   NaN      44000     France      EMEA         Labrune           Janine
# 2689    NJ      94019        USA       NaN           Brown          William
# 2715   NaN      31000     France      EMEA          Roulet          Annette
# 2820   NaN      28034      Spain      EMEA          Freyre            Diego
#
#      DEALSIZE
# 4      Medium
# 7      Medium
# 20      Large
# 25      Large
# 26     Medium
# ...       ...
# 2685   Medium
# 2686   Medium
# 2689    Large
# 2715   Medium
# 2820   Medium
#
# [549 rows x 25 columns]

# %%
# Sorting Data:
# You can sort the data based on a specific column, either in the ascending order or in the descending order.

# For ex-,

df.sort_values("SALES", ascending=False)  # Sorts the data in descending order
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 598         10407               76     100.00                2  14082.80
# 744         10322               50     100.00                6  12536.50
# 53          10424               50     100.00                6  12001.00
# 1062        10412               60     100.00                9  11887.80
# 104         10403               66     100.00                9  11886.60
# ...           ...              ...        ...              ...       ...
# 1818        10419               15      42.67                7    640.05
# 1551        10280               20      28.88               12    577.60
# 2044        10408               15      36.93                1    553.95
# 1287        10407                6      90.19                3    541.14
# 2249        10425               11      43.83                6    482.13
#
#            ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 598   4/22/2005 0:00     On Hold       2         4     2005  ...
# 744   11/4/2004 0:00     Shipped       4        11     2004  ...
# 53    5/31/2005 0:00  In Process       2         5     2005  ...
# 1062   5/3/2005 0:00     Shipped       2         5     2005  ...
# 104    4/8/2005 0:00     Shipped       2         4     2005  ...
# ...              ...         ...     ...       ...      ...  ...
# 1818  5/17/2005 0:00     Shipped       2         5     2005  ...
# 1551  8/17/2004 0:00     Shipped       3         8     2004  ...
# 2044  4/22/2005 0:00     Shipped       2         4     2005  ...
# 1287  4/22/2005 0:00     On Hold       2         4     2005  ...
# 2249  5/31/2005 0:00  In Process       2         5     2005  ...
#
#                       ADDRESSLINE1  ADDRESSLINE2       CITY  STATE POSTALCODE  \
# 598                 3086 Ingle Ln.           NaN   San Jose     CA      94217
# 744       2304 Long Airport Avenue           NaN     Nashua     NH      62005
# 53              C/ Moralzarzal, 86           NaN     Madrid    NaN      28034
# 1062            C/ Moralzarzal, 86           NaN     Madrid    NaN      28034
# 104   Berkeley Gardens 12  Brewery           NaN  Liverpool    NaN    WX1 6LT
# ...                            ...           ...        ...    ...        ...
# 1818                   Geislweg 14           NaN   Salzburg    NaN       5020
# 1551           Via Monte Bianco 34           NaN     Torino    NaN      10100
# 2044                2-2-8 Roppongi           NaN  Minato-ku  Tokyo   106-0032
# 1287                3086 Ingle Ln.           NaN   San Jose     CA      94217
# 2249  67, rue des Cinquante Otages           NaN     Nantes    NaN      44000
#
#       COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 598       USA       NaN           Frick              Sue    Large
# 744       USA       NaN           Young          Valarie    Large
# 53      Spain      EMEA          Freyre            Diego    Large
# 1062    Spain      EMEA          Freyre            Diego    Large
# 104        UK      EMEA           Devon        Elizabeth    Large
# ...       ...       ...             ...              ...      ...
# 1818  Austria      EMEA           Pipps            Georg    Small
# 1551    Italy      EMEA         Accorti            Paolo    Small
# 2044    Japan     Japan       Shimamura            Akiko    Small
# 1287      USA       NaN           Frick              Sue    Small
# 2249   France      EMEA         Labrune           Janine    Small
#
# [2823 rows x 25 columns]

# %%
# We can create pivot tables that summarize the data using specific columns. This is very useful in analyzing the data when you only want to consider the effect of particular columns.

# For ex-,

pd.pivot_table(df, values="SALES", index="CITY", columns="YEAR_ID", aggfunc="sum")
# Out:
# YEAR_ID           2003       2004      2005
# CITY
# Aaarhus       40321.61   60273.94       NaN
# Allentown          NaN  115971.34   6166.80
# Barcelona     48228.51   30183.35       NaN
# Bergamo       96259.03   41696.69       NaN
# Bergen        95277.18   16363.10       NaN
# ...                ...        ...       ...
# Toulouse      55349.32        NaN  15139.12
# Tsawassen          NaN   74634.85       NaN
# Vancouver     38662.21   36576.71       NaN
# Versailles         NaN   64834.32       NaN
# White Plains  38682.95   46873.04       NaN
#
# [73 rows x 3 columns]

# %% [markdown]
# Where,
#
# values: It contains the column for which you want to populate the table's cells.
#
# index: The column used in it will become the row index of the pivot table, and each unique category of this column will become a row in the pivot table.
#
# columns: It contains the headers of the pivot table, and each unique element will become the column in the pivot table.
#
# aggfunc: This is the same aggregator function we discussed earlier.

# %% [markdown]
# ## Continuation

# %% [markdown]
# 6. Combining Data Frames
#
#
# We can combine and merge several data frames either horizontally or vertically. It will concatenate two data frames and return a single merged data frame.
#
# For ex-,
#
# combined_df = pd.concat([df1, df2])
#
#
# You can merge two data frames based on a common column. It is useful when you want to combine two data frames that share a common identifier.
#
# For ex,
#
# merged_df = pd.merge(df1, df2, on="common_col")
#
#
# 7. Applying Custom Functions
#
#
# You can apply custom functions according to your needs in either a row or a column.
#
# For ex-,
#
# def cus_fun(x):
#     return x * 3
#
# df["Sales_Tripled"] = df["SALES"].apply(cus_fun, axis=0)
#
#
# We have written a custom function that will triple the sales value for each row. axis=0 means that we want to apply the custom function on a column, and axis=1 implies that we want to apply the function on a row.
#
# In the earlier method you have to write a separate function and then to call it from the apply() method. Lambda function helps you to use the custom function inside the apply() method itself. Let’s see how we can do that.
#
# df["Sales_Tripled"] = df["SALES"].apply(lambda x: x * 3)
#
#
# Applymap:
#
# We can also apply a custom function to every element of the dataframe in a single line of code. But a point to remember is that it is applicable to all the elements in the dataframe.
#
# For ex-,
#
# df = df.applymap(lambda x: str(x))
#
#
# It will convert the data type to a string of all the elements in the dataframe.
#
#
#
# 8. Time Series Analysis
#
#
# In mathematics, time series analysis means analyzing the data collected over a specific time interval, and pandas have functions to perform this type of analysis.

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1       5/7/2003 0:00   Shipped       2         5     2003  ...
# 2       7/1/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818   12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820    3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822    5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0           897 Long Airport Avenue           NaN            NYC    NY
# 1                59 rue de l'Abbaye           NaN          Reims   NaN
# 2     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2818             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2819                    Torikatu 38           NaN           Oulu   NaN
# 2820             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2821          1 rue Alsace-Lorraine           NaN       Toulouse   NaN
# 2822             8616 Spinnaker Dr.           NaN         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA       NaN              Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA       NaN           Young            Julie   Medium
# 4           NaN      USA       NaN           Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA       NaN         Yoshido             Juri   Medium
#
# [2823 rows x 25 columns]

# %%
# Conversion to DateTime Object Model:

# We can convert the date column into a datetime format for easier data manipulation.

# For ex-,

df["ORDERDATE"] = pd.to_datetime(df["ORDERDATE"])
df

# CHECK THE ABOVE LINE FOR OLD STATE
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0    2003-02-24   Shipped       1         2     2003  ...
# 1    2003-05-07   Shipped       2         5     2003  ...
# 2    2003-07-01   Shipped       3         7     2003  ...
# 3    2003-08-25   Shipped       3         8     2003  ...
# 4    2003-10-10   Shipped       4        10     2003  ...
# ...         ...       ...     ...       ...      ...  ...
# 2818 2004-12-02   Shipped       4        12     2004  ...
# 2819 2005-01-31   Shipped       1         1     2005  ...
# 2820 2005-03-01  Resolved       1         3     2005  ...
# 2821 2005-03-28   Shipped       1         3     2005  ...
# 2822 2005-05-06   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0           897 Long Airport Avenue           NaN            NYC    NY
# 1                59 rue de l'Abbaye           NaN          Reims   NaN
# 2     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2818             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2819                    Torikatu 38           NaN           Oulu   NaN
# 2820             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2821          1 rue Alsace-Lorraine           NaN       Toulouse   NaN
# 2822             8616 Spinnaker Dr.           NaN         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA       NaN              Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA       NaN           Young            Julie   Medium
# 4           NaN      USA       NaN           Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA       NaN         Yoshido             Juri   Medium
#
# [2823 rows x 25 columns]

# %% [markdown]
# Calculate Rolling Average:
#
# Using this method, we can create a rolling window to view data. We can specify a rolling window of any size. If the window size is 5, then it means a 5-day data window at that time. It can help you remove fluctuations in your data and help identify patterns over time.

# %%
rolling_avg = df["SALES"].rolling(window=5).mean()
rolling_avg
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4       3694.642
#           ...
# 2818    2768.990
# 2819    3148.122
# 2820    3786.116
# 2821    3567.472
# 2822    3367.216
# Name: SALES, Length: 2823, dtype: float64

# %% [markdown]
# Cross Tabulation
#
#
# We can perform cross-tabulation between two columns of a table. It is generally a frequency table that shows the frequency of occurrences of various categories. It can help you to understand the distribution of categories across different regions.
#
# For ex-,
#
# Getting a cross-tabulation between the COUNTRY and DEALSIZE.

# %%
cross_tab = pd.crosstab(df["COUNTRY"], df["DEALSIZE"])
cross_tab

#It can show you the order size (‘DEALSIZE’) ordered by different countries.
# Out:
# DEALSIZE     Large  Medium  Small
# COUNTRY
# Australia        7      86     92
# Austria          4      29     22
# Belgium          0      15     18
# Canada           1      33     36
# Denmark          6      31     26
# Finland          5      46     41
# France          21     149    144
# Germany          4      30     28
# Ireland          2       6      8
# Italy            7      44     62
# Japan            3      21     28
# Norway           5      42     38
# Philippines      1      14     11
# Singapore        4      38     37
# Spain           17     171    154
# Sweden           2      31     24
# Switzerland      0      22      9
# UK               4      71     69
# USA             64     505    435

# %% [markdown]
# Handling Outliers
#
#
# Outliers in data means that a particular point goes far beyond the average range. Let’s understand it through an example. Suppose you have 5 points, say 3, 5, 6, 46, 8. Then we can clearly say that the number 46 is an outlier because it is far beyond the average of the rest of the points. These outliers can lead to wrong statistics and should be removed from the dataset.
#
# Here pandas come to the rescue to find these potential outliers. We can use a method called Interquartile Range(IQR), which is a common method for finding and handling these outliers. You can also read about this method if you want information on it. You can read more about them here.
#
# Let’s see how we can do that using pandas.
#
# Q1 = df["SALES"].quantile(0.25)
# Q3 = df["SALES"].quantile(0.75)
# IQR = Q3 - Q1
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR
#
# outliers = df[(df["SALES"] < lower_bound) | (df["SALES"] > upper_bound)]
#
#
# Q1 is the first quartile representing the 25th percentile of the data and Q3 is the third quartile representing the 75th percentile of the data.
#
# lower_bound variable stores the lower bound that is used for finding potential outliers. Its value is set to 1.5 times the IQR below Q1. Similarly, upper_bound calculates the upper bound, 1.5 times the IQR above Q3.
#
# After which, you filter out the outliers that are less than the lower or greater than the upper bound.

# %%
Q1 = df["SALES"].quantile(0.25)
Q3 = df["SALES"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["SALES"] < lower_bound) | (df["SALES"] > upper_bound)]
outliers
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 30          10150               45      100.0                8  10993.50
# 32          10174               34      100.0                4   8014.82
# 35          10206               47      100.0                6   9064.89
# 41          10280               34      100.0                2   8014.82
# 43          10304               47      100.0                6  10172.70
# ...           ...              ...        ...              ...       ...
# 2241        10325               38      100.0                3   8844.12
# 2295        10324               48      100.0                4   8209.44
# 2430        10395               45      100.0                3   8977.05
# 2505        10388               46      100.0                2  10066.60
# 2634        10336               46      100.0                2   9558.80
#
#       ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 30   2003-09-19  Shipped       3         9     2003  ...
# 32   2003-11-06  Shipped       4        11     2003  ...
# 35   2003-12-05  Shipped       4        12     2003  ...
# 41   2004-08-17  Shipped       3         8     2004  ...
# 43   2004-10-11  Shipped       4        10     2004  ...
# ...         ...      ...     ...       ...      ...  ...
# 2241 2004-11-05  Shipped       4        11     2004  ...
# 2295 2004-11-05  Shipped       4        11     2004  ...
# 2430 2005-03-17  Shipped       1         3     2005  ...
# 2505 2005-03-03  Shipped       1         3     2005  ...
# 2634 2004-11-20  Shipped       4        11     2004  ...
#
#                               ADDRESSLINE1  ADDRESSLINE2            CITY  \
# 30    Bronz Sok., Bronz Apt. 3/6 Tesvikiye           NaN       Singapore
# 32                  31 Duncan St. West End           NaN  South Brisbane
# 35                            1900 Oak St.           NaN       Vancouver
# 41                     Via Monte Bianco 34           NaN          Torino
# 43                  67, avenue de l'Europe           NaN      Versailles
# ...                                    ...           ...             ...
# 2241                Erling Skakkes gate 78           NaN         Stavern
# 2295                     2678 Kingston Rd.     Suite 101             NYC
# 2430         27 rue du Colonel Pierre Avia           NaN           Paris
# 2505                     1785 First Street           NaN     New Bedford
# 2634               265, boulevard Charonne           NaN           Paris
#
#            STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME  \
# 30           NaN      79903  Singapore     Japan       Natividad
# 32    Queensland       4101  Australia      APAC        Calaghan
# 35            BC    V3F 2K1     Canada       NaN       Tannamuri
# 41           NaN      10100      Italy      EMEA         Accorti
# 43           NaN      78000     France      EMEA          Tonini
# ...          ...        ...        ...       ...             ...
# 2241         NaN       4110     Norway      EMEA      Bergulfsen
# 2295          NY      10022        USA       NaN           Frick
# 2430         NaN      75508     France      EMEA        Da Cunha
# 2505          MA      50553        USA       NaN         Benitez
# 2634         NaN      75012     France      EMEA        Bertrand
#
#      CONTACTFIRSTNAME DEALSIZE
# 30               Eric    Large
# 32               Tony    Large
# 35              Yoshi    Large
# 41              Paolo    Large
# 43             Daniel    Large
# ...               ...      ...
# 2241            Jonas    Large
# 2295          Michael    Large
# 2430           Daniel    Large
# 2505          Violeta    Large
# 2634            Marie    Large
#
# [81 rows x 25 columns]

# %% [markdown]
# ## Source:- [KDNUGGETS](https://www.kdnuggets.com/10-essential-pandas-functions-every-data-scientist-should-know)
